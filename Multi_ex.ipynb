# %% [markdown]
# <a href="https://colab.research.google.com/github/Predic-learning/AI/blob/main/Multi_ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt

df = pd.read_csv("/content/drive/MyDrive/TempPredict/data.csv")

X = df[['Weight', 'Volume']].values
y = df['CO2'].values.reshape(-1, 1)

regr = linear_model.LinearRegression()
regr.fit(X, y)

#predict the CO2 emission of a car where the weight is 2300kg, and the volume is 1300cm3:
predictedCO2 = regr.predict([[2300, 1300]])

# Plot the data and regression line
plt.scatter(df[['Weight']], y, label='Weight')
plt.scatter(df[['Volume']], y, label='Volume')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

print(predictedCO2)
print(regr.coef_)
# Out:
# [[107.2087328]]
# [[0.00755095 0.00780526]]

# %%
X.shape, y.shape
# Out:
# ((36, 2), (36, 1))
